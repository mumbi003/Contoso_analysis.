# %%
import config

connection_string = f"postgresql://{config.DB_USER}:{config.DB_PASSWORD}@{config.DB_HOST}:{config.DB_PORT}/{config.DB_NAME}"

# %reload_ext sql
# %sql $connection_string

# %% [markdown]
# we find customers that contribute a lot of the total revenue

# %%
# %%sql
# select * from customer limit 2
# Out:
#  * postgresql://postgres:***@localhost:5432/postgres
# 2 rows affected.
# [(15, 4, datetime.date(1990, 9, 10), datetime.date(2034, 7, 29), 'Australia', 'male', 'Mr.', 'Julian', 'A', 'McGuigan', '25 Railway Street', 'CANNING CREEK', 'QLD', 'Queensland', '4357', 'AU', 'Australia', datetime.date(1965, 3, 24), 55, 'Border Patrol agent', 'Cut Rite Lawn Care', '2000 Peugeot Kart Up', -27.831694, 151.166686),
#  (23, 8, datetime.date(1995, 8, 11), datetime.date(2045, 1, 26), 'Australia', 'female', 'Ms.', 'Rose', 'H', 'Dash', '92 Foreshore Road', 'GUILDFORD', 'WA', 'Western Australia', '6055', 'AU', 'Australia', datetime.date(1990, 5, 10), 30, 'Agricultural and food scientist', 'Rack N Sack', '2005 Volvo XC90', -31.919733, 116.047894)]

# %%
# %%sql
# select c.customerkey, c.gender,sum(s.quantity) as quantity, sum(quantity*unitprice) as revenue from sales s
# left join customer c on s.customerkey = c.customerkey
# group by c.customerkey, c.gender
# order by revenue desc
# limit 5
# Out:
#  * postgresql://postgres:***@localhost:5432/postgres
# 5 rows affected.
# [(1743963, 'female', 79, 67855.54040000001),
#  (1375597, 'male', 100, 63250.7515),
#  (1232832, 'male', 33, 62659.8066),
#  (552225, 'female', 38, 62204.3825),
#  (399184, 'male', 83, 60010.02550000001)]
